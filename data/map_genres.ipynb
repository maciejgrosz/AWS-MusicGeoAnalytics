# %%
import json
import re

# %%
genre_types = [
    "pop", "rock", "hip-hop", "jazz", "blues", "country", "rnb",
    "electronic", "classical", "folk", "reggae", "punk", "metal", "indie", "soul",
    "funk", "gospel", "alternative", "rap", "edm", "ska",
    "ambient", "dubstep", "techno", "house", "trap", "latin", "disco", 
    "grunge", "book", "podcast", "trance", "dance", "boogie", "beats", "afrobeat", "phonk"
]
jazz_genres = [
    "dixie",
    "swing",
    "bebop",
    "free",
    "fusion",
    "gypsy",
    "ragtime"
    
]

# %%
def read_music_genres(file_path):
    try:
        with open(file_path, 'r') as file:
            genres = [line.strip() for line in file.readlines()]
        return genres
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []

# %%
file_path = 'unique_genres.txt'
music_genres = read_music_genres(file_path)

if music_genres:
    print("Music Genres:")
    for genre in music_genres:
        print(genre)
else:
    print("No music genres found.")
# Out:
# Music Genres:
#
# #banconversiontherapy
# #melodic house & techno
# #psytrance
# $
# &me
# (mp)
# ***
# +x
# .
# .wav theory
# 001
# 100
# 100bpm
# 2012
# 2015
# 23
# 29.12
# 2dark
# 2step substep
# 35
# 420
# 4eva n a day instrumentals
# 5yearsofgruuv
# 777
# 80's funk
# 80s
# 80s darksynth
# 80s mix
# 89
# 90s dance
# :(
# <3
# ?
# ??*1.000.000*?
# ???
# abgt
# abiotic
# above & beyond
# abstract hip-hop
# accordion
# aches
# acid folk
# acid techno
# acid test
# acoustic
# ade
# adm
# aem
# afro house
# afro trap
# afrobeat
# afropop/afrobeat
# aik0
# airmann
# album
# alex s
# alexis ayaana
# alina piano
# alinabaraz
# all genre
# alle farben
# aloe
# alt-j
# alternative
# alternative
# alternative - indie rock
# alternative electronic
# alternative rock
# alternative/indie
# aluna george
# alunageorge
# ambient
# ambient electronic
# ambient electronica
# ambient/techno
# ambiente
# amsterdam trap
# andre winter
# andthenjust
# angerclub
# anime
# anjunadeep
# anna
# antony and the johnsons
# antypody
# apegang #5452
# aphex
# artist talk
# artpop
# astor piazzolla
# atmospheric
# audio pastel
# audiobooks
# audiomachine
# aurosonic progressive mi
# aussie cabbies
# australian jamming
# awake
# awfs15
# axe fx
# ayya
# azealia banks
# b-sides
# babie lato
# babylon house
# bad
# badoxa
# baile
# bajm
# bajm
# ballad
# ballad #ambient #psychedelic #singer-songwriter
# banboyz
# band perry
# banffmusic
# baroque techno
# bartes
# bass
# bass house
# bass music
# bass/swing/blues
# bassjackers
# battleships #battleshipsband #intime #sydney #indie #triplej #your #words
# bbaran
# beat
# beat
# beat battle
# beats
# beatsampras
# beauville
# bebop
# bee gees
# beesmunt soundsystem
# ben
# ben ufo
# bendelay
# bestof2pacsgreatesthits
# beyonce
# bftd
# bianca casady
# bicep & midland
# big z
# billx
# billy joel
# black metal
# blackcoffee
# blase
# blissco
# blitz the ambassador
# blnk
# bloom child
# blu
# blue
# blues
# blues pills
# bluestep
# bnjmn
# bo
# boehm
# boiler room
# bondax
# bonobo
# the chills
# the gallows
# the magician
# the saints
# the session
# the staves
# the weeknd
# thedumplings
# theory of swing records
# thepremix
# theverypolishcutouts
# theveryyugocutoouts
# thijs haal
# third son
# through the galaxy
# thumper
# tiesto
# timberlicious
# timewheel
# timmy trumpet
# toca
# tomek aposte
# tomodell
# tomorrowland
# tomorrowland house
# tomorrowworld mix
# toro y moi
# touch
# trackstar
# traditional
# trailermusic
# trailerstep
# trance
# trance & progressive
# trance?
# trap
# trapniedisco
# trapstep
# trash
# trashlagoon
# travisscott
# traxsource
# tribal house
# trip-hop
# triphop
# tristesse contemporaine
# tropical
# tropical house
# tropidisco
# truth
# tv girl
# twerk
# twerk champagne
# twine
# twisterz
# twrk
# ty dolla $ign
# tyfr
# underground
# uneducated
# unique
# unkle
# upfront
# uplifting trance
# urban kiz
# urbankiz
# vanic
# variance vibes
# variety
# vibes
# video games
# vina house
# vintage
# vinyls 2007
# violin
# vixa
# vkie
# vlny
# vocal
# vocal chillstep
# vodka
# voice acting
# vol 3.1???
# vraiparle
# waglewski fisz emade
# walapaka
# warsaw 18 november
# wave
# wave, synth
# waysons
# wearemirrorwalk
# weird pop
# weiss
# wekeed
# westcoast
# wildflower
# withyou
# witold ambroziak
# wixa narodowa
# wixapol
# wlm program
# wobble house
# work
# world
# world bass
# wszystko
# wuja cypis
# x
# xavier
# xo
# xxanaxx
# xxanxaxx disappear remix
# yc8
# yellerkin
# young echo
# young thug
# yyu
# zaid jabri
# zamilska
# zayn
# zcr
# zelda
# zenon
# zhu
# zoneout
# zouk / kizomba
# zrk
# zywe srody

# %%
def clean_genre(genre):
    genre = genre.replace('r&b', 'rnb')
    for j_genre in jazz_genres: 
        genre = genre.replace(j_genre, 'jazz')
    cleaned_genre = ''.join(char if char.isalpha() else ' ' for char in genre)
    cleaned_genre = cleaned_genre.strip() 
    cleaned_genre = re.sub(r'\s+', ' ', cleaned_genre)
    return cleaned_genre

# %%
def map_genre(genre, genre_types=genre_types):
    genre = clean_genre(genre)
    genre = genre.split(' ')
    for element in genre: 
        if element in genre_types:
            return element
        elif len(element) >= 3:
            for genre_type in genre_types: 
                if element in genre_type:
                    return genre_type
    for element in genre:
        is_in_how_many = 0
        for genre_type in genre_types:
            if genre_type in element:
                is_in_how_many += 1 
        for genre_type in genre_types:
            if genre_type in element and is_in_how_many == 1:
                return genre_type
    return 'other'

# %%
with open('data_sorted.json', 'r') as data_sorted:
    data_sorted = json.load(data_sorted)

# %%
def map_data(data):
    data_mapped = {}
    for city in data.keys():
        data_mapped[city] = {}
        for genre_name in data[city].keys():
            genre_num = data[city][genre_name]
            new_name = map_genre(genre_name)
            if new_name in data_mapped[city].keys():
                data_mapped[city][new_name] += genre_num
            else:
                data_mapped[city][new_name] = genre_num
                
    return data_mapped

# %%
data_sorted_mapped = map_data(data_sorted)

# %%
with open(f"data_sorted_mapped.json", "w") as outfile: 
        json.dump(data_sorted_mapped, outfile, indent = 4)
